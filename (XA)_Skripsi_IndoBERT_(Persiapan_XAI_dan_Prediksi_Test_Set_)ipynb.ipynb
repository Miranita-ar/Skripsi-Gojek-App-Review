# %% [markdown]
# <a href="https://colab.research.google.com/github/Miranita-ar/Skripsi-Gojek-App-Review/blob/main/(XA)_Skripsi_IndoBERT_(Persiapan_XAI_dan_Prediksi_Test_Set_)ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - CELL 0  : Informasi Notebook
# - CELL 1  : Install Library
# - CELL 2  : Import Library
# - CELL 3  : Mount Google Drive
# - CELL 4  : Project Directory
# - CELL 5  : Membuat Folder XAI
# - CELL 6  : Validasi Folder
# - CELL 7  : Load Tokenizer
# - CELL 8  : Load Model Terbaik
# - CELL 9  : Load Test Dataset
# - CELL 10 : Prediksi Seluruh Test Set
# - CELL 11 : Membuat DataFrame Prediksi
# - CELL 12 : Simpan Output
# - CELL 13 : Summary

# %% [markdown]
# # 1. Persiapan Lingkungan

# %% [markdown]
# ## 1.1 Install Library

# %%
# =====================================================
# CELL 1 : INSTALL LIBRARY
# =====================================================

# !pip install -q transformers datasets accelerate evaluate shap lime
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1.2 Import Library

# %%
# =====================================================
# CELL 2 : IMPORT LIBRARY
# =====================================================

# =====================================================
# Standard Library
# =====================================================

import os
import json
import random
import warnings
from pathlib import Path
from datetime import datetime

# =====================================================
# Data Processing
# =====================================================

import numpy as np
import pandas as pd

# =====================================================
# Visualization
# =====================================================

import matplotlib.pyplot as plt

# =====================================================
# PyTorch
# =====================================================

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader

# =====================================================
# Hugging Face
# =====================================================

from datasets import load_from_disk
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding
)

# =====================================================
# Evaluation
# =====================================================

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    confusion_matrix,
    classification_report
)

warnings.filterwarnings("ignore")

print("="*60)
print("SEMUA LIBRARY BERHASIL DIMUAT")
print("="*60)
# Out:
# ...
# SEMUA LIBRARY BERHASIL DIMUAT
# ...

# %% [markdown]
# ## 1.3 Mount Google Drive

# %%
# =====================================================
# CELL 3 : MOUNT GOOGLE DRIVE
# =====================================================

from google.colab import drive

drive.mount("/content/drive")

print("="*60)
print("GOOGLE DRIVE BERHASIL DIMOUNT")
print("="*60)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1142/1234393721.py in <cell line: 0>()
#       5 from google.colab import drive
#       6
# ----> 7 drive.mount("/content/drive")
#       8
#       9 print("="*60)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %% [markdown]
# ## 1.4 Konfigurasi Project

# %%
# =====================================================
# CELL 4 : PROJECT CONFIGURATION
# =====================================================

# =====================================================
# RANDOM SEED
# =====================================================

RANDOM_STATE = 42

random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(RANDOM_STATE)

# =====================================================
# PROJECT DIRECTORY
# =====================================================

PROJECT_DIR = Path(
    "/content/drive/MyDrive/Skripsi_IndoBERT"
)

# =====================================================
# MODEL
# =====================================================

MODEL_NAME = "Exp1_lr2e5_bs8_ep3"

CHECKPOINT_NAME = "checkpoint-3960"

MODEL_DIR = (
    PROJECT_DIR /
    "models" /
    MODEL_NAME /
    CHECKPOINT_NAME
)

# =====================================================
# TOKENIZER
# =====================================================

TOKENIZER_DIR = (
    PROJECT_DIR /
    "data" /
    "tokenizer"
)

# =====================================================
# TEST DATASET
# =====================================================

TEST_DATASET_DIR = (
    PROJECT_DIR /
    "data" /
    "tokenized" /
    "test_dataset"
)

# =====================================================
# XAI DIRECTORY
# =====================================================

XAI_DIR = PROJECT_DIR / "xai"

print("="*60)
print("PROJECT DIRECTORY")
print("="*60)

print(PROJECT_DIR)
